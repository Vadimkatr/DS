# %% [markdown]
# # Лабораторная работа № 2, 3

# %% [markdown]
# Вариант 10.

# %% [markdown]
# ## Часть 1)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Определяем функцию statistic, которая вычесляет статистики и выводит несолько графиков.

# %%
def statistic(data, name):
    print('Число элементов : ', len(data))
    print('Среднее : ', data.mean())
    print('Min : ', data.min())
    print('Max : ', data.max())
    print('Std : ', data.std())
    print('Median : ', np.median(data))
    first_kvartil = np.percentile(data, 25)
    third_kvartil = np.percentile(data, 75)
    print('25% : ', first_kvartil)
    print('75% : ', third_kvartil)
    print('Межквартильный размах : ', third_kvartil - first_kvartil)
    print('Mode : ', st.mode(data))
    print('Skew : ', st.skew(data))
    print('kurtosis : ', st.kurtosis(data))
    print()
    
    print('Гистограмма:')
    sns.distplot(data, axlabel=name, norm_hist=True)
    plt.show()
    print('\"Ящик с усами\":')
    sns.boxplot(data=data)
    plt.show()
    print('График \"Квантиль квантиль\":')
    res = st.probplot(data, plot=plt)
    plt.show()

# %% [markdown]
# Определяем функцию checkNormalDistr, которая выводит резельтаты примененя трех критериев(Космогорова-Смирнова, Пирсона, функции normaltest(описана ниже)).

# %%
def checkNormalDistr(data, name):
    m, s, size = data.mean(), data.std(), data.size
    
    print('Параметр: ', name, '\n')
    print('Критерий Колмогорова-Смирнова:')
    stat, p = st.kstest(data, 'norm', args=(m, s))
    print('(', stat, p, ')')
    if p < 0.05:
        print('Выборка не подчиняется нормальному закону распределения.')
    else:
        print('Выборка подчиняется нормальному закону распределения.', '\n')

    print('Кси^2 критерий Пирсона:')
    stat, p = st.pearsonr(data, np.random.normal(m, s, size))
    print('(', stat, p, ')')
    if p < 0.05:
        print('Выборка не подчиняется нормальному закону распределения.')
    else:
        print('Выборка подчиняется нормальному закону распределения.', '\n')

    print('Преверим так же функцию normaltest из scipy.stats на принадлежность к нормальному закону распределения')
    stat, p = st.normaltest(data)
    print('(', stat, p, ')')
    if p < 0.05:
        print('Выборка не подчиняется нормальному закону распределения.')
    else:
        print('Выборка подчиняется нормальному закону распределения.', '\n')

# %% [markdown]
# ### normaltest from scipy.stats
# Фукнция normaltest из scipy.stats:
# Проверяте отличается ли выборка от нормального закона распределени (использует D’Agostino’s K^2 Test).
#
# Return:
# statistic: s^2 + k^2, где s - это значение отличия асимметрии выборки от асимметрии норм выборки, так же и с k =  эксцессом.
#
# pvalue: pvalue для проверки нулевой гипотезы.

# %%
all_data = pd.read_csv('data/iris.csv')
# sns.load_dataset('iris')

# %%
all_data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
all_data['variety'].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %% [markdown]
# Удаляем из выборки variety = 'Setosa', т.е. получаем выборку исходя из варианта ( у меня 10 - 'Versicolor' + 'Virginica' )

# %%
data = all_data[all_data['variety'] != 'Setosa']

# %% [markdown]
# Проверим в выборке, соответствующие переменным Sepal.Length, Sepal.Width, Petal.Length, Petal.Width на независимость и однородность;

# %% [markdown]
# ## Sepal length

# %% [markdown]
# Статистика по выборке:

# %%
statistic(data['sepal.length'].values, 'Sepal length')
# Out:
# Число элементов :  100
# Среднее :  6.2620000000000005
# Min :  4.9
# Max :  7.9
# Std :  0.6595119407561929
# Median :  6.3
# 25% :  5.8
# 75% :  6.7
# Межквартильный размах :  0.9000000000000004
# Mode :  ModeResult(mode=array([6.3]), count=array([9]))
# Skew :  0.30391221665575163
# kurtosis :  -0.13998536126102668
#
# Гистограмма:
# "Ящик с усами":
# График "Квантиль квантиль":

# %%
checkNormalDistr(data['sepal.length'].values, 'Sepal length')
# Out:
# Параметр:  Sepal length
#
# Критерий Колмогорова-Смирнова:
# ( 0.06712824156506314 0.7774386320464353 )
# Выборка подчиняется нормальному закону распределения.
#
# Кси^2 критерий Пирсона:
# ( -0.11241988217433353 0.265451149831173 )
# Выборка подчиняется нормальному закону распределения.
#
# Преверим так же функцию normaltest из scipy.stats на принадлежность к нормальному закону распределения
# ( 1.68241023557088 0.43119057476175415 )
# Выборка подчиняется нормальному закону распределения.

# %% [markdown]
# ## Sepal width

# %%
statistic(data['sepal.width'].values, 'Sepal width')
# Out:
# Число элементов :  100
# Среднее :  2.8719999999999994
# Min :  2.0
# Max :  3.8
# Std :  0.3310830711468045
# Median :  2.9
# 25% :  2.7
# 75% :  3.025
# Межквартильный размах :  0.32499999999999973
# Mode :  ModeResult(mode=array([3.]), count=array([20]))
# Skew :  0.036638816527154026
# kurtosis :  0.4099377152403103
#
# Гистограмма:
# "Ящик с усами":
# График "Квантиль квантиль":

# %%
checkNormalDistr(data['sepal.width'].values, 'Sepal width')
# Out:
# Параметр:  Sepal width
#
# Критерий Колмогорова-Смирнова:
# ( 0.10047749395469097 0.24828973970414192 )
# Выборка подчиняется нормальному закону распределения.
#
# Кси^2 критерий Пирсона:
# ( -0.004961079978166999 0.9609293663523115 )
# Выборка подчиняется нормальному закону распределения.
#
# Преверим так же функцию normaltest из scipy.stats на принадлежность к нормальному закону распределения
# ( 1.2307463417525872 0.5404391815118519 )
# Выборка подчиняется нормальному закону распределения.

# %% [markdown]
# ## Pelat length

# %%
statistic(data['petal.length'].values, 'Petal length')
# Out:
# Число элементов :  100
# Среднее :  4.906
# Min :  3.0
# Max :  6.9
# Std :  0.8214401986754728
# Median :  4.9
# 25% :  4.375
# 75% :  5.525
# Межквартильный размах :  1.1500000000000004
# Mode :  ModeResult(mode=array([4.5]), count=array([8]))
# Skew :  0.16849664932580463
# kurtosis :  -0.36822358233361063
#
# Гистограмма:
# "Ящик с усами":
# График "Квантиль квантиль":

# %%
checkNormalDistr(data['petal.length'].values, 'Petal length')
# Out:
# Параметр:  Petal length
#
# Критерий Колмогорова-Смирнова:
# ( 0.06665015765400073 0.7876964914023983 )
# Выборка подчиняется нормальному закону распределения.
#
# Кси^2 критерий Пирсона:
# ( 0.09937064706722873 0.32528745841609785 )
# Выборка подчиняется нормальному закону распределения.
#
# Преверим так же функцию normaltest из scipy.stats на принадлежность к нормальному закону распределения
# ( 0.9420830007914336 0.6243516670325002 )
# Выборка подчиняется нормальному закону распределения.

# %% [markdown]
# ### Petal width

# %%
statistic(data['petal.width'].values, 'Petal width')
# Out:
# Число элементов :  100
# Среднее :  1.6760000000000006
# Min :  1.0
# Max :  2.5
# Std :  0.4226393261399133
# Median :  1.6
# 25% :  1.3
# 75% :  2.0
# Межквартильный размах :  0.7
# Mode :  ModeResult(mode=array([1.3]), count=array([13]))
# Skew :  0.22935412729808102
# kurtosis :  -1.029100838660789
#
# Гистограмма:
# "Ящик с усами":
# График "Квантиль квантиль":

# %%
checkNormalDistr(data['petal.width'].values, 'Petal width')
# Out:
# Параметр:  Petal width
#
# Критерий Колмогорова-Смирнова:
# ( 0.1414525744423759 0.03296204981017237 )
# Выборка не подчиняется нормальному закону распределения.
# Кси^2 критерий Пирсона:
# ( 0.02777368038169466 0.7838557159661895 )
# Выборка подчиняется нормальному закону распределения.
#
# Преверим так же функцию normaltest из scipy.stats на принадлежность к нормальному закону распределения
# ( 16.769312363109435 0.00022834425405067528 )
# Выборка не подчиняется нормальному закону распределения.

# %% [markdown]
# # Часть 2

# %% [markdown]
# Диаграмма рассеяния (также точечная диаграмма, англ. scatter plot) — математическая диаграмма, изображающая значения двух переменных в виде точек на декартовой плоскости.
#
# На диаграмме рассеяния каждому наблюдению (или элементарной единице набора данных) соответствует точка, координаты которой (в декартовой системе координат) равны значениям двух каких-то параметров этого наблюдения. Если предполагается, что один из параметров зависит от другого, то обычно значения независимого параметра откладывается по горизонтальной оси, а значения зависимого — по вертикальной. Диаграммы рассеяния используются для демонстрации наличия или отсутствия корреляции между двумя переменными.

# %%
cols = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']
sns_plot = sns.pairplot(all_data[cols])

# %% [markdown]
# Построим матрицу корреляций, и оценим коррелируемость данных:

# %% [markdown]
# Если ковариация положительна, то с ростом значений одной случайной величины, значения второй имеют тенденцию возрастать, а если знак отрицательный — то убывать.
#
# Однако только по абсолютному значению ковариации нельзя судить о том, насколько сильно величины взаимосвязаны, так как её масштаб зависит от их дисперсий. Масштаб можно отнормировать, поделив значение ковариации на произведение среднеквадратических отклонений (квадратных корней из дисперсий). При этом получается так называемый коэффициент корреляции Пирсона, который всегда находится в интервале от −1 до 1

# %%
all_data.corr()
# np.corrcoef(data['sepal.length'], data['sepal.width'])
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# Значение коэффициента меняется от −1 (последовательности рангов полностью противоположны) до +1 (последовательности рангов полностью совпадают). Нулевое значение показывает, что признаки независимы.

# %% [markdown]
# (Для красивого вывода, оформим ее через цветную матрицу)

# %%
corr = data.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# Введем нулевую гипотезу : "пара переменных являеться коррелированной". Оценим статическую значимость на уровне $eps <= 0.05$. То есть при pvalue <= 0.05 мы отклоняем нулевую гипотезу.

# %%
columns = all_data.columns.drop('variety')

# %%
for num, i in enumerate(columns):
    for j in columns[num:]:
        print(" %.15s %.19s %f " % (i, j, st.pearsonr(all_data[i], all_data[j])[1]))
# Out:
#  sepal.length sepal.length 0.000000
#  sepal.length sepal.width 0.151898
#  sepal.length petal.length 0.000000
#  sepal.length petal.width 0.000000
#  sepal.width sepal.width 0.000000
#  sepal.width petal.length 0.000000
#  sepal.width petal.width 0.000004
#  petal.length petal.length 0.000000
#  petal.length petal.width 0.000000
#  petal.width petal.width 0.000000

# %% [markdown]
# В результате получаеться, что пара "sepal.length sepal.width" являеться не коррелированной.

# %% [markdown]
# ### Часть 3.1

# %% [markdown]
# Удаляем параметр, для которого не отклоняеться гипотезя о нормальном распределении:

# %%
data.head()
# Out:
#     sepal.length  sepal.width  petal.length
# 50           7.0          3.2           4.7
# 51           6.4          3.2           4.5
# 52           6.9          3.1           4.9
# 53           5.5          2.3           4.0
# 54           6.5          2.8           4.6

# %%
data = data.drop(['petal.width', 'variety'], axis=1)

# %% [markdown]
# Считаем вектор математических ожиданий и матрицу ковариаций:

# %%
mean_of_data = data.mean()
cov_of_data = data.cov()

# %% [markdown]
# Для проверки на МНР, изобразим 3D модели нашей выборки:

# %%
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

#Parameters to set
mu_x = data['sepal.length'].mean()
variance_x = np.var(data['sepal.length'])

mu_y = data['sepal.width'].mean()
variance_y = np.var(data['sepal.width'])

#Create grid and multivariate normal
x = data['sepal.length']
y = data['sepal.width']
X, Y = np.meshgrid(x, y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
ax.set_xlabel('sepal.length')
ax.set_ylabel('sepal.width')
ax.set_zlabel('Z axis')
plt.show()

# %%
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

#Parameters to set
mu_x = data['petal.length'].mean()
variance_x = np.var(data['petal.length'])

mu_y = data['sepal.width'].mean()
variance_y = np.var(data['sepal.width'])

#Create grid and multivariate normal
x = data['petal.length']
y = data['sepal.width']
X, Y = np.meshgrid(x, y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
ax.set_xlabel('petal.length')
ax.set_ylabel('sepal.width')
ax.set_zlabel('Z axis')
plt.show()

# %%
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

#Parameters to set
mu_x = data['petal.length'].mean()
variance_x = np.var(data['petal.length'])

mu_y = data['sepal.length'].mean()
variance_y = np.var(data['sepal.length'])

#Create grid and multivariate normal
x = data['petal.length']
y = data['sepal.length']
X, Y = np.meshgrid(x, y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
ax.set_xlabel('petal.length')
ax.set_ylabel('sepal.length')
ax.set_zlabel('Z axis')
plt.show()

# %% [markdown]
# Немного извращения из R:

# %%
import rpy2.robjects as robjects
from rpy2.robjects import r
from rpy2.robjects.numpy2ri import numpy2ri
from rpy2.robjects.packages import importr

# %%
# Taking the variable from Python to R
r_resi = numpy2ri(data.values)

# Creating this variable in R (from python)
r.assign("resi", r_resi)

# Calling libraries in R 
r('library("mvnormtest")')

# Calling a function in R (from python)
r("res <- mshapiro.test(t(resi))")

# Retrieving information from R to Python
r_result = r("res")

# Printing the output in python
print(r_result)
# Out:
# size  [1] 100   3
#
#
# 	Shapiro-Wilk normality test
#
# data:  Z
# W = 0.95976, p-value = 0.003867

# %% [markdown]
# Исходя из Shapiro-Wilk normality test, мы можем сделать вывод, что наша выборка не принадлежит многомерному нормальному распределению.

# %% [markdown]
# ### 3.2

# %% [markdown]
# Вектор $x^1$ сосвавлен из вектора $(x_1)$, $x^2$ из $(x_2, x_3)$.

# %% [markdown]
# Вычислим условное математическое ожидание:

# %%
mu1_2 = mean_of_data[0] + data.iloc[:,[0]].cov().values * np.linalg.inv(data.iloc[:,[1, 2]].cov()).dot((data.iloc[:,[1, 2]] - mean_of_data[1:].values).T)

# %%
mu1_2.mean()
# Out:
# 6.261999999999995

# %% [markdown]
# Условная ковариационная матрица:

# %%
cov_of_data.iloc[0,[0]].values - cov_of_data['sepal.length']['sepal.width'] * \
np.linalg.inv(data.iloc[:,[1, 2]].cov()) * cov_of_data.iloc[0,[1]].values
# Out:
# array([[0.25468012, 0.47803908],
#        [0.47803908, 0.40934979]])

# %% [markdown]
# Вектор $x^1$ сосвавлен из вектора $(x_1, x_2)$, $x^2$ из $(x_3)$.

# %% [markdown]
# Условное математическое ожидание:

# %%
mu2_3 = mean_of_data[0:2].values + 1 / cov_of_data.values[2][2] * data.iloc[:,[0, 1]].cov().values.dot((data.iloc[:,[0, 1]] - mean_of_data[2]).T).T

# %%
np.mean([i[0] for i in mu2_3]), np.mean([i[1] for i in mu2_3])
# Out:
# (6.7715359444190835, 2.7846068847774945)

# %% [markdown]
# Условная ковариационная матрица:

# %%
cov_of_data.iloc[:2,[0, 1]].values - cov_of_data.iloc[2,[0, 1]].values * 1 / cov_of_data.iloc[2,[2]].values * cov_of_data.iloc[2,[0, 1]].values.T
# Out:
# array([[ 0.13779015,  0.09224078],
#        [-0.17940177,  0.08080643]])
